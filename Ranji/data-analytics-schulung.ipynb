# %% [markdown]
# <div class="alert alert-block alert-info"><b>Szenario</b>
#
# Du bist seit Jahresanfang bei der General Data Analytics GmbH angestellt.
# Dein Unternehmen erstellt für Kunden auf Wunsch eine umfangreiche Analyse der Organisationstruktur.
# Nun beauftragt euch die Internationale Berufsgenossenschaft für die Informationstechnik eine umfassende Marktanalyse zu erstellen.
# Dabei handelt es sich im wesentlichen um das durchschnittliche Gehalt eines Angestellten im IT-Sektor weltweit.
# **Ziel dabei ist es, einen Überblick darüber zu gewinnen, wie unterschiedlich die Menschen je nach Region verdienen**.
# Deine Firma beauftragt dich diesen Datensatz dahingehend zu analysieren und bei der nächsten Konferenz deine Ergebnisse in einer schönen Grafik vorzustellen.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info"><b>Szenario</b>
#
# Als Datenquelle stellt dir die Data Analytics GmbH den folgenden Datensatz zur Verfügung: <font color='red'>*data-analytics-gehalt.csv*</font>
#
# </div>

# %% [markdown]
# Folgenden Spalten sind in dieser CSV-Datei enthalten. Zu jeder Spalte findest Du eine Erklärung zu den dazugehörigen Werten.

# %% [markdown]
# ![image.png](attachment:119aa581-a73c-407d-a340-6fa9029bf004.png)

# %% [markdown]
# <div class="alert alert-block alert-warning"><b>Definition</b>
#
# Eine CSV-Datei ist ein **einfacher Textdateiformat**, das verwendet wird, um **tabellarische Daten zu speichern**, indem die Werte in den einzelnen Zellen **durch Kommas getrennt** werden. Es kann in Programmen wie Tabellenkalkulationen geöffnet und bearbeitet werden. Microsoft Excell arbeitet nach einem ähnlichen Prinzip.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning"><b>Definition</b>
#
# ![image.png](attachment:1291b4cb-4ac9-41e7-9195-3bc57758ec20.png)
#
# </div>

# %% [markdown]
# Schauen wir uns zunächst an, ob die Datei <font color='red'>*data_analytics_schulung.csv*</font> überhaupt für uns zugänglich ist. Drucke den Inhalt des <font color='blue'>*input-Ordners*</font> und schaue, ob sich dort die <font color='red'>*data_analytics_schulung.csv*</font> finden lässt.
# Um in den <font color='blue'>*input*-Ordner</font> zu gelangen müssen wir zunächst eine Ebene in der Ordnerstruktur nach oben gehen. Das ganze erreichen wir durch ein <span style="background-color: #ED7EFF;">*../*-Command</span> innerhalb der <span style="background-color: #ED7EFF;">os.listdir()-Methode</span>, um vom aktuellen Arbeitsordner eine Ebene nach oben zu gelangen. Von dort aus müssen wir in den <font color='blue'>*input-Ordner*</font> gelangen. Schlussendlich sieht die Anweisung wie folgt aus, um den Inhalt des <font color='blue'>*input-Ordners*</font> auszugeben:

# %% [markdown]
# <span style="background-color: #ED7EFF;">
#     os.listdir("../input")
# </span>

# %%
#Beispiel: Überprüfugen ob der person-Ordner im input-Ordner sind
import os
if "personen" in os.listdir("../input"):
    print(True)
print(os.listdir("../input"))
# Out:
# True
# ['personen', 'data-analytics-gehalt']

# %% [markdown]
# Wie können wir den Inhalt des personen-Ordners einsehen mit der os.listdir()-Methode? Hast du eventuell schon eine Idee?

# %%
#Beispiel: Inhalt des personen-Ordners einsehen

print(os.listdir("../input/personen"))
# Out:
# ['Personen.csv']

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Glückwunsch!</b>
#
# Sehr gut! Nun wissen wir, dass in dem personen-Ordner die Datei "personen.csv" liegt, welche unseren Beispieldatensatz enthält. Dieser kann nun jetzt eingelesen werden! :)
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning"><b>Definition</b>
#
# Mit dem **os-Modul** von Python, können wir auf unser **Betriebssystem zugreifen**. Das Modul liefert Funktionen, um bspw. Ordner zu ertellen, zu löschen, umzubenennen und vieles mehr. In unserem Fall möchten wir aber nachsehen, welche Dateien im aktuellen Arbeitsordner entahlten sind. Auch das erreichen wir mithilfe des mächtigen **os-Moduls** in Python. Ist die Datei <font color='red'>*data_analytics_schulung.csv*</font> in unserem aktuellen Arbeitsordner? Gib den Inhalt des <font color='blue'>*input-Ordners*</font> aus und versuche von dort durch den <span style="background-color: #ED7EFF;"><font color='black'>os.listdir()-Befehl</font></span> den Weg zur <font color='red'>*data_analytics_schulung.csv*</font> zu finden.
#
# </div>

# %%
#Füge hier deinen Code ein

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Glückwunsch!</b>
#
#  Sehr gut, <font color='red'>*data_analytics_schulung.csv*</font> liegt im **data-analytics-gehalt** Ordner. Jetzt wollen wir diese Datei in unseren Python-Code einlesen, um damit arbeiten zu können. Auch hierzu stellt Python selbstverständlich ein Modul bereit. Dieses Modul heißt <span style="background-color: #ED7EFF;"><font color='black'>pandas</font></span>. <span style="background-color: #ED7EFF;"><font color='black'>*Pandas*</font></span> ist ein Werkzeug, um Daten zu analysieren, extrahieren und um Erkenntnisse aus diesen Daten zu gewinnen. <span style="background-color: #ED7EFF;"><font color='black'>*Pandas*</font></span> macht es uns sehr leicht, um unsere Daten zunächst einzulesen und uns einen groben Überblick über diese zu geben.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning"><b>Definition</b>
#
#
# In Python werden Module in der Regel mit bestimmten Kurzformen importiert. Man gibt dem importierten Modul während des Imports gerne einen Alias bzw. Nickname mit, über welches man das gewünschte Modul schneller und einfacher ansprechen kann. <span style="background-color: #ED7EFF;"><font color='black'>*Pandas*</font></span> wird mit der Kurzform <span style="background-color: #ED7EFF;"><font color='black'>*pd*</font></span> importiert. Führe die folgende Codezeile aus um <span style="background-color: #ED7EFF;"><font color='black'>*Pandas*</font></span> zu importieren.
#
# </div>

# %%
import pandas as pd

# %% [markdown]
# Im folgenden werden wir nun unsere Beispieldatei<font color='red'> "*personen.csv*" </font>  mit pandas einlesen. Du wirst sehen, wie schnell und leicht das geht, wenn man weiß, wo sich die gewünschte befindet.

# %%
import pandas as pd
pd.read_csv('../input/personen/Personen.csv', sep=';')
# Out:
#    vorname   nachname  alter
# 0   Hristo    Tsindas     23
# 1  Michlin       Mann     16
# 2    Benji      Bonjo     25
# 3   Sercan   Guerloka     20
# 4  Torsten    Bürsche     20
# 5    Alina  Geschwind     19

# %% [markdown]
# Die Tabelle welche du nun im obenstehenden Output siehst, ist ein sogenanntes pandas <font color='blue'>*DataFrame*</font>. Dieses speichern wir in der gängigen Variable <font color='blue'>*df*</font> ab, um im späteren Codeverlauf darauf zugreifen zu können.

# %%
import pandas as pd
df = pd.read_csv('../input/personen/Personen.csv', sep=';')
df
# Out:
#    vorname   nachname  alter
# 0   Hristo    Tsindas     23
# 1  Michlin       Mann     16
# 2    Benji      Bonjo     25
# 3   Sercan   Guerloka     20
# 4  Torsten    Bürsche     20
# 5    Alina  Geschwind     19

# %% [markdown]
# <div class="alert alert-block alert-warning"><b>Definition</b>
#
# Ein <font color='blue'>*DataFrame*</font> ist in vielerlei Hinsicht anders als eine <font color='blue'>*list*</font>, obwohl beide mehrere Datenpunkte speichern können. Der offensichtlichste Unterschied ist, dass <font color='blue'>*DataFrames*</font> zweidimensional sind mit Zeilen und Spalten, während <font color='blue'>*Listen*</font> eindimensional sind.
# Der Datentyp <font color='blue'>*DataFrame*</font> hat ein paar sehr nützliche Attribute, also in der Variable versteckte Werte. Wie bereits im Notebook zuvor beschrieben, kann man Attribute daran erkennen, von sich durch einen Punkt vom Objekt getrennt werden und ohne runde Klammern geschrieben werden.
# Schauen wir uns dazu beispielhaft das <font color='red'>*my_df.shape*-Attribut</font> an. Es gibt die Anzahl der Zeilen und Spalten eines <font color='blue'>*DataFrames*</font> wieder.
#
# </div>

# %% [markdown]
# #Bild von Lara: Unterschied Liste und DataFrame

# %% [markdown]
# <div class="alert alert-block alert-info"><b>Szenario</b>
#
# Jetzt bist Du an der Reihe! Immportiere nun die <font color='red'> *data_analytics_schulung.csv* </font> und speichere sie als *DataFrame* *df* ab und gib dir das *DataFrame* aus!
#
# </div>

# %%
#Füge hier deinen Code ein

# %% [markdown]
# <div class="alert alert-block alert-danger"><b>Achtung</b>
#
# Bestimmt wunderst du dich, dass dein DataFrame nicht so aussieht, wie in unserem Beispiel. Die Spalten wurden offensichtlich nicht richtig eingelesen. Pandas liest standardweise eine CSV-Datei mit dem <font color='blue'>Seperator "," </font> ein, aber unsere Datei nutzt ein <font color='blue'>Semikolon ";"</font> , um Zellenwerte voneinander zu trennen. Dies müssen wir der <font color='blue'>*pd.read_csv()-Methode*</font> als Argument mitgeben.
#
# </div>

# %% [markdown]
# Lies nun die *data_analytics_schulung.csv* erneut als DataFrame df ein und gib der pd.read_csv() neben dem Dateinamen nun auch den richtigen Seperator ";" mit.

# %%
#Füge hier deinen Code ein

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Glückwunsch!</b>
#
# Das DataFrame wurde nun erfolgreich eingelesen und in der Variable df abespeichert! Herzlichen Glückwunsch!
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning"><b>Definition</b>
#
# Um schnell auf den Inhalt deines DataFrames df zugreifen zu können, gibt es im wesentlichen 3 Wege, welche uns diese Jupyter-Notebooks-Umgebung bietet
# * df -- Gibt das gesamte DataFrame in der Konsole zurück
# * df.head(<gewünschte Zeilenanzahl>)-- Gibt Standardweise die ersten 5 Zeilen eines DataFrames zurück (Außer man gibt der Methode als Argument eine gewünschte Zeilenanzahl mit)
# * df.tail(<gewünschte Zeilenanzahl>) -- Gibt Standardweise die letzten 5 Zeilen eines DataFrames zurück (Außer man gibt der Methode als Argument eine gewünschte Zeilenanzahl mit)
#
# </div>

# %% [markdown]
# ![image.png](attachment:3f26d8c6-a54c-455b-af74-3529de4ca09f.png)

# %% [markdown]
# ![image.png](attachment:8fab5a0f-332f-4c8a-b826-d11cd119a55d.png)

# %% [markdown]
# ![image.png](attachment:72db7be9-38ea-4f78-95e4-07d8d74cc996.png)

# %% [markdown]
# <div class="alert alert-block alert-warning"><b>Definition</b>
#
# Lies nun im folgenden unsere *data_analytics_schulung.csv* ein, speichere sie als *DataFrame df* ab.
# * Gib das **gesamte df** schnell in der Konsole aus
# * Gib die **ersten 8 Zeilen** von df aus
# * Gib die **letzten 5 Zeilen** von df aus
#
# </div>

# %%
#Füge hier deinen Code ein
